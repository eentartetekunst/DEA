# %%
import pandas as pd
Calu3_12h_DEGs = pd.read_csv('Calu3_12h_DEGs.csv', sep=',')
Calu3_4h_DEGs = pd.read_csv('Calu3_4h_DEGs.csv', sep=',')
h1299_36h_DEGs = pd.read_csv('h1299_36h_DEGs.csv', sep=',')
h1299_4h_DEGs = pd.read_csv('h1299_4h_DEGs.csv', sep=',')

# %%
h1299_36h_DEGs
# Out:
#         Unnamed: 0     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 0  ENSG00000197061  8454.284303        0.635919  0.135315  4.699533  0.000003
# 1  ENSG00000124575   230.382182       -0.900892  0.222154 -4.055255  0.000050
#
#        padj
# 0  0.040793
# 1  0.391724

# %% [markdown]
# H4 clustered histone 3
# H1.3 linker histone, cluster member

# %%
h1299_4h_DEGs= h1299_4h_DEGs.sort_values

# %%
h1299_4h_DEGs
# Out:
#           Unnamed: 0    baseMean  log2FoldChange     lfcSE      stat  \
# 241  ENSG00000205085   42.015590       -2.038266  0.477417 -4.269366
# 590  ENSG00000238649   41.754975       -1.930533  0.553850 -3.485661
# 272  ENSG00000265787   48.074581       -1.834860  0.439574 -4.174176
# 3    ENSG00000128965  474.957183       -1.527367  0.205016 -7.449984
# 694  ENSG00000205090   45.571952       -1.520664  0.467038 -3.255972
# ..               ...         ...             ...       ...       ...
# 843  ENSG00000018236   45.921595        1.298200  0.436464  2.974356
# 47   ENSG00000165617  192.501580        1.318272  0.240850  5.473405
# 2    ENSG00000159167  651.507890        1.435378  0.173402  8.277769
# 1    ENSG00000166592  431.547393        1.812637  0.187453  9.669802
# 662  ENSG00000119922   41.690010        1.870088  0.558131  3.350625
#
#            pvalue          padj
# 241  1.960295e-05  9.430056e-04
# 590  4.909219e-04  8.846527e-03
# 272  2.990668e-05  1.290797e-03
# ...

# %% [markdown]
# ENSG00000205085	golgi associated RAB2 interactor 1A
#
# ENSG00000238649 small nucleolar RNA, C/D box 42A
#
#
#
# ENSG00000265787 cytochrome P450 family 4 subfamily F member 35, pseudogene
#
#
#
# ENSG00000128965 ChaC glutathione specific gamma-glutamylcyclotransferase 1
#
#
# ENSG00000205090
# transmembrane protein 240
#
#
# ENSG00000018236  contactin 1
# a member of the immunoglobulin superfamily. It is a glycosylphosphatidylinositol (GPI)-anchored neuronal membrane protein that functions as a cell adhesion molecule. It may play a role in the formation of axon connections in the developing nervous system. Multiple alternatively spliced transcript variants encoding different isoforms have been found for this gene. [provided by RefSeq, Dec 2011]
#
#
#
# ENSG00000165617	 dishevelled binding antagonist of beta catenin 1
#
#
# ENSG00000166592 RAD, Ras related glycolysis inhibitor and calcium channel regulator
#
#
# ENSG00000159167   stanniocalcin 1 (may play a role in the regulation of renal and intestinal calcium and phosphate transport, cell metabolism, or cellular calcium/phosphate homeostasis. Overexpression of human stanniocalcin 1 in mice produces high serum phosphate levels, dwarfism, and increased metabolic rate. This gene has altered expression in hepatocellular, ovarian, and breast cancers; implicated in various biological processes including angiogenesis ( A Nguyen · 2009))
#
# Stanniocalcin-1 secreted by human umbilical mesenchymal stem cells regulates interleukin-10 expression via the PI3K/AKT/mTOR pathway in alveolar macrophages. [https://www.sciencedirect.com/science/article/abs/pii/S1043466622003234]
#
# ENSG00000119922 interferon induced protein with tetratricopeptide repeats 2

# %% [markdown]
# # Calu, 12hpi

# %%
Calu3_12h_DEGs=Calu3_12h_DEGs.sort_values(by='log2FoldChange')
Calu3_12h_DEGs
# Out:
#            Unnamed: 0    baseMean  log2FoldChange     lfcSE       stat  \
# 196   ENSG00000171855  930.514174      -11.112226  1.050074 -10.582324
# 683   ENSG00000197110  132.139375      -10.692488  2.034816  -5.254770
# 385   ENSG00000183709  241.512516      -10.134690  1.399710  -7.240564
# 322   ENSG00000182393  391.833480       -9.777255  1.212247  -8.065399
# 497   ENSG00000225492   52.417957       -9.352029  1.490920  -6.272657
# ...               ...         ...             ...       ...        ...
# 1358  ENSG00000183688   67.235919        1.510687  0.392371   3.850146
# 2225  ENSG00000106123   28.350738        1.610844  0.585832   2.749668
# 1695  ENSG00000166823   41.014845        1.615789  0.473352   3.413507
# 2339  ENSG00000230561   21.037631        1.682819  0.649994   2.588975
# 2264  ENSG00000118271   19.251816        1.853616  0.685389   2.704475
#
#             pvalue          padj
# 196   3.599199e-26  2.502083e-24
# 683   1.482098e-07  2.967446e-06
# ...

# %% [markdown]
# ENSG00000171855 interferon beta 1
# ENSG00000197110 interferon lambda 3
# ENSG00000183709 Interferon lambda 2
# ENSG00000182393 interferon lambda 1
# ENSG00000225492 guanylate binding protein 1 pseudogene 1
#
# ENSG00000183688 refilin B (Involved in the regulation of the perinuclear actin network and nuclear shape through interaction with filamins. Plays an essential role in the formation of cartilaginous skeletal elements.)
#
# ENSG00000106123 EPH receptor B6 ( transmembrane proteins that function as receptors for ephrin-B family protein. Activity of this protein can influence cell adhesion and migration. Expression of this gene is downregulated during tumor progression, suggesting that the protein may suppress tumor invasion and metastasis)
#
#
# ENSG00000166823 mesoderm posterior bHLH transcription factor 1 (Enables DNA-binding transcription factor activity and transcription cis-regulatory region binding activity. Involved in several processes, including endothelial cell differentiation; heart development; and positive regulation of transcription by RNA polymerase II. Predicted to be part of chromatin. Predicted to be active in nucleus. [provided by Alliance of Genome Resources, Apr 2022]
# )
#
#
# ENSG00000230561  coiled-coil domain containing 192  (function is not clear)
#
#
# ENSG00000118271 transthyretin ( transthyretin, is a negative acute phase-reactant produced in the liver that acts as a transport protein for thyroxine and is used as a marker of nutrition.) [https://www.frontiersin.org/articles/10.3389/fmed.2021.638529/full]

# %% [markdown]
# # Calu3 4 hpi

# %%
Calu3_4h_DEGs = Calu3_4h_DEGs.sort_values(by='log2FoldChange')
Calu3_4h_DEGs
# Out:
#           Unnamed: 0     baseMean  log2FoldChange     lfcSE      stat  \
# 33   ENSG00000285294   479.067933       -0.745338  0.167462 -4.450800
# 65   ENSG00000239650   386.353647       -0.742280  0.193351 -3.839024
# 48   ENSG00000153294   418.922764       -0.714075  0.168860 -4.228799
# 77   ENSG00000118263   536.405264       -0.664135  0.182016 -3.648772
# 103  ENSG00000263503   532.686247       -0.660317  0.219582 -3.007158
# ..               ...          ...             ...       ...       ...
# 64   ENSG00000100526   471.571073        0.650537  0.169284  3.842882
# 2    ENSG00000187840  4844.628679        0.654048  0.108288  6.039900
# 40   ENSG00000125454   591.060624        0.656152  0.153431  4.276533
# 10   ENSG00000163170  1425.425318        0.664565  0.135576  4.901789
# 60   ENSG00000019582  1212.582288        0.688896  0.176851  3.895355
#
#            pvalue      padj
# 33   8.555112e-06  0.001578
# 65   1.235242e-04  0.007845
# 48   2.349424e-05  0.002660
# ...

# %% [markdown]
# ENSG00000285294 long intergenic non-protein coding RNA 842
#
# ENSG00000239650  GUSB pseudogene 4
#
#
# ENSG00000153294 adhesion G protein-coupled receptor F4
#
#
# ENSG00000118263 KLF transcription factor 7
#
# ENSG00000263503 mitogen-activated protein kinase 8 interacting protein 1 pseudogene
# ________________________________________________________
#
# ENSG00000100526 cyclin dependent kinase inhibitor 3
#
# ENSG00000187840 eukaryotic translation initiation factor 4E binding protein 1
#
#
# ENSG00000125454 solute carrier family 25 member 19 = a mitochondrial thiamine pyrophosphate carrier
#
# ENSG00000163170 bolA family member 3
#
#
#
# ENSG00000019582 CD74 (англ. HLA class II histocompatibility antigen gamma chain; HLA-DR antigens-associated invariant chain)
